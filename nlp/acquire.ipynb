# %% [markdown]
# Codeup Blog Articles
#
# Scrape the article text from the following pages:
#
# https://codeup.com/codeups-data-science-career-accelerator-is-here/
#
# https://codeup.com/data-science-myths/
#
# https://codeup.com/data-science-vs-data-analytics-whats-the-difference/
#
# https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/
#
# https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:

# %%
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

from acquire import get_blog_articles

# %% [markdown]
# News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# Business
# Sports
# Technology
# Entertainment
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }
#
# Hints:
#
# Start by inspecting the website in your browser. Figure out which elements will be useful.
#
# Start by creating a function that handles a single article and produces a dictionary like the one above.
#
# Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
#
# Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.

# %%
def get_sub_list(topic_url):
    '''
    Takes in a topic url and returns a sub_list of dictionaries for that topic
    '''
    # make web request using selected url
    headers = {'User-Agent': 'Technomancer'}
    response = get(topic_url, headers=headers)

    # cerate soup object
    soup = BeautifulSoup(response.text)

    # get articles from soup object
    articles = soup.select(".news-card")
    
    # create empty list
    sub_list = []
    
    # itterate through articles 
    for article in articles:
        
        # use soup object to identify title, content and catagory of article
        title = article.select("[itemprop='headline']")[0].get_text()
        content = article.select("[itemprop='articleBody']")[0].get_text()
        category = response.url.split("/")[-1]

        # create dictionary with title, content, and catagory and append it to the sub_list
        sub_list.append({"title":title,"content":content,"category":category})

    # return sub_list
    return sub_list

# %%
def get_news_articles():
    
    # create list of topic URLs
    topic_urls = [
            "https://inshorts.com/en/read/business",
            "https://inshorts.com/en/read/sports",
            "https://inshorts.com/en/read/technology",
            "https://inshorts.com/en/read/entertainment"
            ]
    
    # create empty master list
    master_list = []
    
    # itterate through topic urls
    for topic_url in topic_urls:
        
        # call pass topic URL to get_sublist and append resulting sub_list to master list
        # use .extend to flatten list
        sub_list = get_sub_list(topic_url)
        
        master_list.extend(sub_list)
    
    df = pd.DataFrame(master_list)
    
    df.to_csv('inshorts_news_articles.csv')
    
    return df

# %%
get_news_articles()
# Out:
#          category                                            content  \
# 0        business  The RBI on Thursday kept the repo rate unchang...
# 1        business  Former Finance Minister P Chidambaram on Thurs...
# 2        business  Congress leader P Chidambaram walked out of Ti...
# 3        business  Google Co-founders Sergey Brin and Larry Page ...
# 4        business  Tesla and SpaceX founder and CEO Elon Musk, in...
# 5        business  In a bid to provide relief to depositors of sc...
# 6        business  The Finance Ministers of several states met Un...
# 7        business  Nirav Modi has been declared a fugitive econom...
# 8        business  Airtel has said it would raise up to ₹21,500 c...
# 9        business  The RBI on Thursday lowered its GDP growth for...
# 10       business  Vistara Chief Commercial Officer Sanjiv Kapoor...
# 11       business  Reliance Jio on Wednesday unveiled new prepaid...
# 12       business  Roh Soh-yeong, the wife of South Korean conglo...
# 13       business  Swedish manufacturer Saab has said it wants to...
# 14       business  The Indonesian government has decided to fire ...
# 15       business  The Initial Public Offering of Ujjivan Small F...
# 16       business  Ford and McDonald's have partnered for a proje...
# 17       business  A study by a British organisation that certifi...
# 18       business  Over 92,000 employees of BSNL and MTNL have op...
# 19       business  Shares of Kerala-based CSB Bank listed at 41% ...
# 20       business  IL&FS has reported a loss of ₹22,527 crore for...
# 21       business  Canada Pension Plan Investment Board (CPPIB) w...
# 22       business  The Reserve Bank of India (RBI) has raised its...
# 23       business  State Bank of India will cut its stake in mutu...
# 24       business  RBI Governor Shaktikanta Das said central bank...
# 25         sports  During a Mzansi Super League match against Dur...
# 26         sports  On December 4, 2009, Virender Sehwag was dismi...
# 27         sports  Pakistani fans criticised opener Imam-ul-Haq o...
# 28         sports  Legend Don Bradman smashed 185 runs to help Au...
# 29         sports  Former Pakistan all-rounder Abdul Razzaq has s...
# ..            ...                                                ...
# 70     technology  After Google fired four employees over violati...
# 71     technology  India has ranked 73rd out of 152 countries lis...
# 72     technology  Language-learning app Duolingo raised $30 mill...
# 73     technology  The Parliamentary Standing Committee on Women ...
# 74     technology  A study by a British organisation that certifi...
# 75  entertainment  'La La Land' actress Emma Stone got engaged to...
# 76  entertainment  Singer Justin Timberlake has apologised to his...
# 77  entertainment  Speaking about their 23-year age gap, Leonardo...
# 78  entertainment  Speaking about battling mental health issues, ...
# 79  entertainment  Malayalam adult film actress Shakeela has clai...
# 80  entertainment  Actress Bhumi Pednekar in an interview to Zoom...
# 81  entertainment  Speaking about the growing age gap between Bol...
# 82  entertainment  Bigg Boss 13 contestant Arhaan Khan has been a...
# 83  entertainment  Singer Neha Kakkar took to Instagram Story to ...
# 84  entertainment  The Churchgate Government Railway Police has a...
# 85  entertainment  Hrithik Roshan has been voted the sexiest Asia...
# 86  entertainment  American singer Jason Derulo has revealed that...
# 87  entertainment  Actor Hrithik Roshan has shared a report on Tw...
# 88  entertainment  Daniel Shravan, a filmmaker, has been criticis...
# 89  entertainment  When asked about 53-year-old Salman Khan roman...
# 90  entertainment  Actor Randeep Hooda dislocated his patella whi...
# 91  entertainment  Director Shoojit Sircar on Wednesday took to T...
# 92  entertainment  Singer and actress Shibani Dandekar recalled a...
# 93  entertainment  Rishi Kapoor got criticised on Twitter for cal...
# 94  entertainment  Deepika Padukone, in an interview with The New...
# 95  entertainment  American media personality Kim Kardashian reve...
# 96  entertainment  Actress Priyanka Chopra, who is UNICEF's Goodw...
# 97  entertainment  Deepika Padukone has said that she continues t...
# 98  entertainment  Talking about working with 'Love Aaj Kal 2' di...
# 99  entertainment  Actor Asha Parekh revealed in an interview tha...
#
#                                                 title
# 0   RBI keeps repo rate unchanged at 5.15% after f...
# 1   8, 7, 6.6, 5.8, 5 & 4.5 is the state of econom...
# 2   P Chidambaram walks out of Tihar Jail after 10...
# 3   Google Co-founders gain $2.3B after Sundar Pic...
# 4   Musk says in court his net worth is around $20...
# 5   Maharashtra govt suggests merger of PMC Bank w...
# 6   Feel embarrassed to ask, govt must pay: States...
# 7   Nirav Modi declared fugitive economic offender...
# 8   Airtel to raise up to ₹21,500 crore after SC r...
# 9   RBI cuts India's GDP growth forecast for the c...
# 10  Our crew are human too: Vistara after user pos...
# 11  Jio to hike tariffs by up to 39% from December...
# 12  S Korea's SK Group Chairman's wife files for d...
# 13  Want control of manufacturing if we win $15bn ...
# 14  Indonesia fires flag carrier's CEO for smuggli...
# 15  Ujjivan Small Finance Bank IPO becomes 2019's ...
# 16  Ford to use McDonald's coffee bean waste to ma...
# 17  6 tech giants contributed to $100 bn 'tax gap'...
# 18  Over 92,000 BSNL, MTNL employees opted for VRS...
# 19  CSB Bank share lists at 41% premium to issue p...
# 20      IL&FS reports ₹22,527 crore net loss for FY19
# 21  Canada's CPPIB to invest up to $600 mn through...
# 22  RBI raises peer-to-peer lending limit five-tim...
# 23  SBI to cut 8% stake in UTI mutual fund through...
# 24  RBI has good idea of vulnerabilities in NBFC s...
# 25  South African bowler celebrates wicket with ma...
# 26  Sehwag fell short by 7 runs to become 1st play...
# 27  Pak fans criticise Imam-ul-Haq over laughing p...
# 28  Bradman once hit 185 in 1 innings, India score...
# 29  Virat a good player but can't be put in same c...
# ..                                                ...
# 70  Fired Google employees to charge firm with unf...
# 71  India ranks 73rd in UN index assessing e-comme...
# 72  Duolingo raises $30 million from Alphabet's Ca...
# 73  Parliamentary panel on women meets Facebook to...
# 74  6 tech giants contributed to $100 bn 'tax gap'...
# 75  'La La Land' actress Emma Stone gets engaged; ...
# 76  Justin Timberlake apologises to wife over pics...
# 77  People should date who they want to: DiCaprio'...
# 78  Was in Goa, wanted to walk into ocean & never ...
# 79  Adult film star claims Censor Board members de...
# 80  I stalk Priyanka Chopra on social media, I thi...
# 81  If I was 50, I would feel odd romancing a 22-y...
# 82  Bigg Boss 13's Arhaan Khan accused of cheating...
# 83  Neha Kakkar criticises comedy act for mocking ...
# 84  Man stalks, assaults TV actress and ex-Splitsv...
# 85  Hrithik Roshan voted sexiest Asian male of the...
# 86  I've underwear on: Jason Derulo after Instagra...
# 87  I've friends who're better than me: Hrithik on...
# 88  Filmmaker says 'women should carry condoms, co...
# 89  Ask him only: Sonakshi when asked about Salman...
# 90  Randeep Hooda dislocates knee during stunt, ca...
# 91  Check your filmy ethics before lecturing: Shoo...
# 92  I can't imagine living my life with no fear fo...
# 93  Rishi gets criticised for calling The Irishman...
# 94  All I wanted to do was sleep: Deepika on fight...
# 95  I've gotten rid of plastic bottles: Kim after ...
# 96  Priyanka Chopra receives UNICEF's Danny Kaye H...
# 97  I've to feel butterflies in my stomach: Deepik...
# 98  Imtiaz Ali has changed my acting process, pers...
# 99  I loved a married director but didn't want to ...
#
# [100 rows x 3 columns]
