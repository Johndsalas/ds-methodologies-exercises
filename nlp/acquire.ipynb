# %%
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

from acquire import get_blog_articles, get_news_articles

# %% [markdown]
# Codeup Blog Articles
#
# Scrape the article text from the following pages:
#
# https://codeup.com/codeups-data-science-career-accelerator-is-here/
#
# https://codeup.com/data-science-myths/
#
# https://codeup.com/data-science-vs-data-analytics-whats-the-difference/
#
# https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/
#
# https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:

# %%
get_blog_articles()
# Out:
# '[{\'title\': \'Codeup’s Data Science Career Accelerator is Here! - Codeup\', \'article\': \'\\nThe rumors are true! The time has arrived. Codeup has officially opened applications to our new Data Science career accelerator, with only 25 seats available! This immersive program is one of a kind in San Antonio, and will help you land a job in\\xa0Glassdoor’s #1 Best Job in America.\\nData Science is a method of providing actionable intelligence from data.\\xa0The data revolution has hit San Antonio,\\xa0resulting in an explosion in Data Scientist positions\\xa0across companies like USAA, Accenture, Booz Allen Hamilton, and HEB. We’ve even seen\\xa0UTSA invest $70 M for a Cybersecurity Center and School of Data Science.\\xa0We built a program to specifically meet the growing demands of this industry.\\nOur program will be 18 weeks long, full-time, hands-on, and project-based. Our curriculum development and instruction is led by Senior Data Scientist, Maggie Giust, who has worked at HEB, Capital Group, and Rackspace, along with input from dozens of practitioners and hiring partners. Students will work with real data sets, realistic problems, and the entire data science pipeline from collection to deployment. They will receive professional development training in resume writing, interviewing, and continuing education to prepare for a smooth transition to the workforce.\\nWe focus on applied data science for immediate impact and ROI in a business, which is how we can back it all up with a 6 month tuition refund guarantee – just like our existing Web Dev program. We’re focusing on Data Science with Python, SQL, and ML, covered in\\xa014 modules: 1) Fundamentals; 2) Applied statistics; 3) SQL; 4) Python; 5) Supervised machine learning – regression; 6) Supervised machine learning – classification; 7) Unsupervised machine learning – clustering; 8) Time series analysis; 9) Anomaly detection; 10) Natural language processing; 11) Distributed machine learning; 12) Advanced topics (deep learning, NoSQL, cloud deployment, etc.); 13) Storytelling with data; and 14) Domain expertise development.\\nApplications are now open\\xa0for Codeup’s first Data Science cohort, which will start class on February 4, 2019. Hurry – there are only 25 seats available! To further our mission of cultivating inclusive growth, scholarships will be available to women, minorities, LGBTQIA+ individuals, veterans, first responders, and people relocating to San Antonio.\\nIf you want to learn about joining our program or hiring our graduates, email datascience@codeup.com!\\n\'}, {\'title\': \'Data Science Myths - Codeup\', \'article\': \'\\nBy Dimitri Antoniou and Maggie Giust\\nData Science, Big Data, Machine Learning, NLP, Neural Networks…these buzzwords have rapidly spread into mainstream use over the last few years. Unfortunately, definitions are varied and sources of truth are limited. Data Scientists are in fact not magical unicorn wizards who can snap their fingers and turn a business around! Today, we’ll take a cue from our favorite Mythbusters to tackle some common myths and misconceptions in the field of Data Science.\\n\\nvia GIPHY\\nMyth #1: Data Science = Statistics\\nAt first glance, this one doesn’t sound unreasonable. Statistics is defined as, “A branch of mathematics dealing with the collection, analysis, interpretation, and presentation of masses of numerical data.” That sounds a lot like our definition of Data Science: a method of drawing actionable intelligence from data. \\nIn truth, statistics is actually one small piece of Data Science. As our Senior Data Scientist puts it, “Statistics forces us to make assumptions about the nature of the relationship between variables, the distribution of the data, etc.” In the traditional Data Science venn diagram, you’ll see that math/stats make up ⅓ of a working professional. These are tools and skills to leverage, but data science itself is about drawing intelligence from data.\\nBUSTED\\n\\nvia GIPHY\\n\\xa0 ...

# %% [markdown]
# News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# Business
# Sports
# Technology
# Entertainment
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
# {
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }
#
# Hints:
#
# Start by inspecting the website in your browser. Figure out which elements will be useful.
#
# Start by creating a function that handles a single article and produces a dictionary like the one above.
#
# Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
#
# Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.

# %%
df = get_news_articles()

# %%
df.category.value_counts()
# Out:
# business         25
# entertainment    25
# technology       25
# sports           25
# Name: category, dtype: int64

# %%
df
# Out:
#     Unnamed: 0       category  \
# 0            0       business
# 1            1       business
# 2            2       business
# 3            3       business
# 4            4       business
# 5            5       business
# 6            6       business
# 7            7       business
# 8            8       business
# 9            9       business
# 10          10       business
# 11          11       business
# 12          12       business
# 13          13       business
# 14          14       business
# 15          15       business
# 16          16       business
# 17          17       business
# 18          18       business
# 19          19       business
# 20          20       business
# 21          21       business
# 22          22       business
# 23          23       business
# 24          24       business
# 25          25         sports
# 26          26         sports
# 27          27         sports
# 28          28         sports
# 29          29         sports
# ..         ...            ...
# 70          70     technology
# 71          71     technology
# 72          72     technology
# 73          73     technology
# 74          74     technology
# 75          75  entertainment
# 76          76  entertainment
# 77          77  entertainment
# 78          78  entertainment
# 79          79  entertainment
# 80          80  entertainment
# 81          81  entertainment
# 82          82  entertainment
# 83          83  entertainment
# 84          84  entertainment
# 85          85  entertainment
# 86          86  entertainment
# 87          87  entertainment
# 88          88  entertainment
# 89          89  entertainment
# 90          90  entertainment
# 91          91  entertainment
# 92          92  entertainment
# 93          93  entertainment
# 94          94  entertainment
# 95          95  entertainment
# 96          96  entertainment
# 97          97  entertainment
# 98          98  entertainment
# 99          99  entertainment
#
#                                               content  \
# 0   The RBI on Thursday kept the repo rate unchang...
# 1   Former Finance Minister P Chidambaram on Thurs...
# 2   Google Co-founders Sergey Brin and Larry Page ...
# 3   Google's 47-year-old India-born CEO Sundar Pic...
# 4   SoftBank Founder and CEO Masayoshi Son, in a d...
# 5   Tesla and SpaceX founder and CEO Elon Musk, in...
# 6   Nirav Modi has been declared a fugitive econom...
# 7   In a bid to provide relief to depositors of sc...
# 8   The Asian Development Bank (ADB) has approved ...
# 9   The RBI on Thursday lowered its GDP growth for...
# 10  The Indonesian government has decided to fire ...
# 11  An RBI survey showed that consumer confidence ...
# 12  Vodafone Idea Chairman Kumar Mangalam Birla ha...
# 13  Air India's loss in 2018-19 has been provision...
# 14  Swedish manufacturer Saab has said it wants to...
# 15  State-controlled oil giant Saudi Aramco has ra...
# 16  The RBI has said it is investigating the two-d...
# 17  A study by a British organisation that certifi...
# 18  Maruti Suzuki India has announced a recall of ...
# 19  Canada Pension Plan Investment Board (CPPIB) w...
# 20  Sue Desmond-Hellmann, the CEO of Bill & Melind...
# 21  The Reserve Bank of India (RBI) has raised its...
# 22  IL&FS has reported a loss of ₹22,527 crore for...
# 23  RBI Governor Shaktikanta Das has said that the...
# 24  RBI Governor Shaktikanta Das said central bank...
# 25  During a Mzansi Super League match against Dur...
# 26  Former Pakistan all-rounder Abdul Razzaq has s...
# 27  Italian newspaper 'Corriere dello Sport' has b...
# 28  Former England captain Bob Willis has died at ...
# 29  Off-spinner Ravichandran Ashwin has said that ...
# ..                                                ...
# 70  Google is developing a Maps feature that shows...
# 71  Qualcomm has announced it will create referenc...
# 72  India is the fifth-worst country in terms of p...
# 73  A study by a British organisation that certifi...
# 74  Facebook has filed a lawsuit against Hong Kong...
# 75  After a troll called Sonakshi Sinha "biggest c...
# 76  Speaking at the Hindustan Times Leadership Sum...
# 77  American singer R Kelly was charged with bribi...
# 78  Pooja Bhatt said that her half-sister Alia Bha...
# 79  Actor Hrithik Roshan has shared a report on Tw...
# 80  Commenting on the killing of the 4 accused in ...
# 81  Speaking about battling mental health issues, ...
# 82  Malayalam adult film actress Shakeela has clai...
# 83  Sanjay Dutt revealed on a TV show that he used...
# 84  The shooting of Emraan Hashmi and Amitabh Bach...
# 85  Comedian Gaurav Gera has apologised to singer ...
# 86  Sanjay Kapoor's daughter Shanaya Kapoor has sa...
# 87  Akshay Kumar has said he doesn't want any kind...
# 88  Actor Jason Momoa took to Instagram to apologi...
# 89  After the four men accused of gangraping and m...
# 90  Actress Priyanka Chopra has been named as the ...
# 91  Singer Armaan Malik has revealed that he went ...
# 92  Malayalam film director VA Shrikumar Menon was...
# 93  Actress Raveena Tandon took to Instagram to sh...
# 94  Actress Sonakshi Sinha, who made her Bollywood...
# 95  Pankaj Kapur has joined the cast of the Hindi ...
# 96  Farhan Akhtar's production house, Excel Entert...
# 97  Singer and actress Shibani Dandekar recalled a...
# 98  Deepika Padukone, in an interview with The New...
# 99  On being asked if comparisons with Sara Ali Kh...
#
#                                                 title
# 0   RBI keeps repo rate unchanged at 5.15% after f...
# 1   8, 7, 6.6, 5.8, 5 & 4.5 is the state of econom...
# 2   Google Co-founders gain $2.3B after Sundar Pic...
# 3   Sundar Pichai rejected Google shares worth mil...
# 4   Gut feeling drove me to invest $20M in Alibaba...
# 5   Musk says in court his net worth is around $20...
# 6   Nirav Modi declared fugitive economic offender...
# 7   Maharashtra govt suggests merger of PMC Bank w...
# 8   Asian Development Bank approves $1 billion eme...
# 9   RBI cuts India's GDP growth forecast for the c...
# 10  Indonesia fires flag carrier's CEO for smuggli...
# 11  RBI survey shows Indian consumers most pessimi...
# 12  Vodafone Idea will have to shut shop if there'...
# 13  Air India's loss in 2018-19 provisionally esti...
# 14  Want control of manufacturing if we win $15bn ...
# 15  Saudi Aramco raises $25.6 billion in world's b...
# 16  RBI probing net banking and mobile banking out...
# 17  6 tech giants contributed to $100 bn 'tax gap'...
# 18  Maruti Suzuki India to recall over 63,000 unit...
# 19  Canada's CPPIB to invest up to $600 mn through...
# 20  Gates Foundation CEO Sue Desmond-Hellmann to s...
# 21  RBI raises peer-to-peer lending limit five-tim...
# 22      IL&FS reports ₹22,527 crore net loss for FY19
# 23  India could launch its own cryptocurrency, say...
# 24  RBI has good idea of vulnerabilities in NBFC s...
# 25  South African bowler celebrates wicket with ma...
# 26  Virat a good player but can't be put in same c...
# 27  Italian paper labels clash of black footballer...
# 28  Former England captain Bob Willis dies aged 70...
# 29  Who doesn't want to represent India in T20 Wor...
# ..                                                ...
# 70  Google Maps develops feature to show brightly ...
# 71  Qualcomm to develop AR glasses with Pokémon GO...
# 72  India 5th worst country for biometric data pri...
# 73  6 tech giants contributed to $100 bn 'tax gap'...
# 74  Facebook sues Hong Kong-based firm 'ILikeAd' f...
# 75  Hu mai, kya karloge: Sonakshi after troll call...
# 76  Have applied for Indian passport, hurts me to ...
# 77  Singer R Kelly charged with bribing govt offic...
# 78  Alia is successful as she didn't inherit our f...
# 79  I've friends who're better than me: Hrithik on...
# 80  Der aaye, durust aaye: Jaya Bachchan on killin...
# 81  Was in Goa, wanted to walk into ocean & never ...
# 82  Adult film star claims Censor Board members de...
# 83  Made paper bags in jail for 10p each, used mon...
# 84  Shooting of Emraan's Chehre stalled after fans...
# 85  I'm no one to tell her anything: Gera apologis...
# 86  I'd get emotional and just die if Karan ever d...
# 87  I never wanted the tag of an action hero: Aksh...
# 88  Sorry: Jason to Chris after criticising him fo...
# 89  Bravo Telangana Police: Rishi Kapoor on Hydera...
# 90  Priyanka Chopra tops IMDb 2019 list of Indian ...
# 91  I was bullied in school, that kind of scarred ...
# 92  Director Menon arrested, let off on bail after...
# 93  Raveena Tandon shares throwback pic of her dau...
# 94  I learnt a lot of things by just observing Sal...
# 95  After four years, Shahid and dad Pankaj to reu...
# 96  Farhan to produce biopic on mathematician Vash...
# 97  I can't imagine living my life with no fear fo...
# 98  All I wanted to do was sleep: Deepika on fight...
# 99  It motivates me: Ananya Panday on comparisons ...
#
# [100 rows x 4 columns]
