# %%
import json
import pandas as pd

# %%
with open('AllCards.json') as f:
    df = json.load(f)

# %%
df = pd.DataFrame(df)

# %%
df = df.T

# %%
df.shape
# Out:
# (20504, 35)

# %%
df.columns
# Out:
# Index(['colorIdentity', 'colorIndicator', 'colors', 'convertedManaCost',
#        'edhrecRank', 'faceConvertedManaCost', 'foreignData', 'hand',
#        'hasNoDeckLimit', 'isReserved', 'layout', 'leadershipSkills',
#        'legalities', 'life', 'loyalty', 'manaCost', 'mtgArenaId', 'mtgoFoilId',
#        'mtgoId', 'name', 'names', 'otherFaceIds', 'power', 'printings',
#        'purchaseUrls', 'rulings', 'scryfallOracleId', 'side', 'subtypes',
#        'supertypes', 'text', 'toughness', 'type', 'types', 'uuid'],
#       dtype='object')

# %%
df.colorIndicator.value_counts() # Drop
# Out:
# [R]          26
# [G]          25
# [B]          18
# [U]          14
# [W]           9
# [G, R]        3
# [B, R, U]     1
# [G, R, W]     1
# [B, G]        1
# Name: colorIndicator, dtype: int64

# %%
df.colorIdentity.value_counts()
# Out:
# [B]                3086
# [R]                3067
# [W]                3063
# [U]                3044
# [G]                3028
# []                 2278
# [B, U]              289
# [B, R]              289
# [U, W]              286
# [G, W]              286
# [G, R]              280
# [B, G]              208
# [B, W]              206
# [R, U]              200
# [R, W]              198
# [G, U]              193
# [B, G, R, U, W]      68
# [B, R, U]            64
# [G, R, W]            60
# [B, G, R]            58
# [G, U, W]            53
# [B, U, W]            50
# [B, R, W]            31
# [B, G, U]            30
# [R, U, W]            29
# [B, G, W]            25
# [G, R, U]            24
# [B, G, U, W]          3
# [G, R, U, W]          2
# [B, R, U, W]          2
# [B, G, R, W]          2
# [B, G, R, U]          2
# Name: colorIdentity, dtype: int64

# %%
df.colors.value_counts()
# Out:
# []                 3095
# [W]                3091
# [B]                3076
# [R]                3070
# [G]                3051
# [U]                3032
# [B, R]              206
# [U, W]              203
# [G, W]              202
# [B, U]              200
# [G, R]              199
# [B, G]              149
# [B, W]              143
# [R, U]              141
# [G, U]              139
# [R, W]              138
# [B, R, U]            42
# [G, R, W]            38
# [B, G, R]            36
# [G, U, W]            35
# [B, U, W]            34
# [B, G, R, U, W]      30
# [B, G, U]            19
# [B, R, W]            19
# [R, U, W]            18
# [G, R, U]            15
# [B, G, W]            14
# [W, G]                9
# [U, R]                7
# [W, B]                7
# [W, U]                7
# [R, G]                7
# [W, R]                7
# [U, G]                7
# [U, B]                7
# [B, G, U, W]          3
# [B, G, R, W]          2
# [B, R, U, W]          2
# ...

# %%
df.convertedManaCost.value_counts().head()
# Out:
# 3.0    4643
# 2.0    4079
# 4.0    3794
# 5.0    2394
# 1.0    2175
# Name: convertedManaCost, dtype: int64

# %%
df.edhrecRank.value_counts().head()
# Out:
# 14309    2
# 18693    2
# 587      2
# 5361     2
# 8976     2
# Name: edhrecRank, dtype: int64

# %%
df.faceConvertedManaCost.value_counts()
# Out:
# 0.0    107
# 2.0    100
# 3.0     90
# 4.0     59
# 1.0     48
# 5.0     25
# 6.0     16
# 7.0      6
# Name: faceConvertedManaCost, dtype: int64

# %%
df.foreignData.value_counts() # drop
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
df.hand.value_counts()
# Out:
# +0    40
# +1    27
# -1    20
# +2     7
# -2     7
# +3     4
# -4     1
# -3     1
# Name: hand, dtype: int64

# %%
df.hasNoDeckLimit.value_counts()
# Out:
# True    4
# Name: hasNoDeckLimit, dtype: int64
