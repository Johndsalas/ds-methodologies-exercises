# %%
#ignore warning
import warnings
warnings.filterwarnings('ignore')

#Wrangling
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

#Exploring
import scipy.stats as stats

#Visualizing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import acquire
import summarize
import prepare

# Load the tips dataset from either pydataset or seaborn.
from pydataset import data

from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

import wrangle_mall as wm

from pydataset import data
from sklearn.preprocessing import scale

# %%
df_tips = data('tips')

# %%
df_tips.head()
# Out:
#             total_bill                  tip     sex smoker  day    time  size
# 1                16.99                 1.01  Female     No  Sun  Dinner     2
# 2                10.34                 1.66    Male     No  Sun  Dinner     3
# 3                21.01                 3.50    Male     No  Sun  Dinner     3
# 4                23.68                 3.31    Male     No  Sun  Dinner     2
# 5                24.59                 3.61  Female     No  Sun  Dinner     4

# %%
X_3d = df_tips[['tip','total_bill','size']]

kmeans = KMeans(n_clusters=4)
kmeans.fit(X_3d)

centers_3d = pd.DataFrame(kmeans.cluster_centers_, columns=X_3d.columns)

# %matplotlib inline

fig = plt.figure(figsize=(12, 9))
ax = Axes3D(fig)

ax.scatter(X_3d.tip, X_3d.total_bill, X_3d.size, c=kmeans.labels_)
ax.scatter(centers_3d.tip, centers_3d.total_bill, centers_3d.size, c='pink',s=10000, alpha=.4)
ax.set(xlabel='tip', ylabel='total', zlabel='size')
# Out:
# [Text(0.5, 0, 'size'), Text(0.5, 0, 'total'), Text(0.5, 0, 'tip')]

# %%
X_3d.head
# Out:
#                    tip           total_bill  size
# 1                 1.01                16.99     2
# 2                 1.66                10.34     3
# 3                 3.50                21.01     3
# 4                 3.31                23.68     2
# 5                 3.61                24.59     4

# %%
kmeans.labels_
# Out:
# array([0, 2, 0, 3, 3, 3, 2, 3, 0, 0, 2, 1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 0,
#        0, 1, 0, 0, 2, 2, 0, 0, 2, 0, 0, 0, 0, 3, 0, 0, 0, 3, 0, 0, 2, 2,
#        3, 0, 0, 3, 3, 0, 2, 2, 1, 2, 3, 0, 1, 3, 2, 1, 0, 2, 2, 0, 0, 0,
#        0, 2, 0, 0, 2, 0, 3, 3, 2, 2, 0, 3, 3, 0, 0, 0, 2, 3, 0, 1, 2, 0,
#        3, 0, 3, 0, 2, 0, 3, 1, 3, 2, 0, 2, 2, 0, 1, 0, 0, 0, 0, 3, 0, 2,
#        2, 2, 1, 3, 3, 0, 3, 2, 2, 3, 2, 2, 2, 0, 2, 3, 2, 2, 2, 3, 0, 0,
#        2, 2, 0, 2, 2, 2, 0, 2, 0, 1, 1, 3, 0, 2, 0, 2, 2, 2, 2, 2, 0, 3,
#        0, 3, 1, 3, 2, 0, 0, 2, 0, 2, 0, 3, 0, 3, 2, 2, 1, 0, 2, 3, 0, 3,
#        0, 2, 2, 1, 1, 3, 1, 3, 1, 0, 0, 3, 0, 3, 0, 0, 3, 0, 0, 2, 2, 1,
#        2, 2, 0, 2, 2, 0, 0, 0, 3, 1, 3, 2, 3, 3, 1, 2, 3, 2, 3, 2, 2, 3,
#        2, 2, 2, 0, 2, 0, 2, 0, 2, 0, 3, 0, 2, 2, 0, 2, 2, 3, 1, 3, 3, 0,
#        0, 0], dtype=int32)
