# %%
import wrangle_mall as wm

# %%
df_mall=wm.get_mallcustomer_data()
df_mall.head()
# Out:
#              gender  age  annual_income  spending_score
# customer_id
# 1              Male   19             15              39
# 2              Male   21             15              81
# 3            Female   20             16               6
# 4            Female   23             16              77
# 5            Female   31             17              40

# %%
wm.df_summary(df_mall)
# Out:
# --- Shape: (200, 4)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
# gender            200 non-null object
# age               200 non-null int64
# annual_income     200 non-null int64
# spending_score    200 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB
# --- Descriptions
#         gender         age  annual_income  spending_score
# count      200  200.000000     200.000000      200.000000
# unique       2         NaN            NaN             NaN
# top     Female         NaN            NaN             NaN
# freq       112         NaN            NaN             NaN
# mean       NaN   38.850000      60.560000       50.200000
# std        NaN   13.969007      26.264721       25.823522
# min        NaN   18.000000      15.000000        1.000000
# 25%        NaN   28.750000      41.500000       34.750000
# 50%        NaN   36.000000      61.500000       50.000000
# ...

# %%
k=1.5
df=df_mall
df_mall = wm.add_outlier_columns(df, k)
df_mall.head()
# Out:
#              gender  age  annual_income  spending_score  age_outliers  \
# customer_id
# 1              Male   19             15              39             0
# 2              Male   21             15              81             0
# 3            Female   20             16               6             0
# 4            Female   23             16              77             0
# 5            Female   31             17              40             0
#
#              annual_income_outliers  spending_score_outliers
# customer_id
# 1                               0.0                        0
# 2                               0.0                        0
# 3                               0.0                        0
# 4                               0.0                        0
# 5                               0.0                        0

# %%
df_mall.shape
# Out:
# (200, 7)

# %%
df = df_mall
test, train = wm.split(df,train_pct=.7)

# %%
test.shape
# Out:
# (60, 7)

# %%
train.shape
# Out:
# (140, 7)

# %%
col_name = 'gender'
test, train, = wm.one_hot_encode(train, test, col_name)
test.drop(columns='gender',inplace=True)
train.drop(columns='gender',inplace=True)

# %%
train.head()
# Out:
#              age  annual_income  spending_score  age_outliers  \
# customer_id
# 43            48             39              36             0
# 192           32            103              69             0
# 27            45             28              32             0
# 45            49             39              28             0
# 42            24             38              92             0
#
#              annual_income_outliers  spending_score_outliers  Female  Male
# customer_id
# 43                              0.0                        0     0.0   1.0
# 192                             0.0                        0     1.0   0.0
# 27                              0.0                        0     1.0   0.0
# 45                              0.0                        0     1.0   0.0
# 42                              0.0                        0     0.0   1.0

# %%
wm.nulls_by_col(train)
# Out:
#                          num_rows_missing  pct_rows_missing
# age                                     0               0.0
# annual_income                           0               0.0
# spending_score                          0               0.0
# age_outliers                            0               0.0
# annual_income_outliers                  0               0.0
# spending_score_outliers                 0               0.0
# Female                                  0               0.0
# Male                                    0               0.0

# %%
wm.nulls_by_col(test)
# Out:
#                          num_rows_missing  pct_rows_missing
# age                                     0               0.0
# annual_income                           0               0.0
# spending_score                          0               0.0
# age_outliers                            0               0.0
# annual_income_outliers                  0               0.0
# spending_score_outliers                 0               0.0
# Female                                  0               0.0
# Male                                    0               0.0

# %%
train_scaled, test_scaled, scaler = wm.standard_scaler(train,test)

# %%
train_scaled.head()
# Out:
#           age  annual_income  spending_score  age_outliers  \
# 43   0.731840      -0.814526       -0.599688           0.0
# 192 -0.444988       1.583028        0.672378           0.0
# 27   0.511185      -1.226606       -0.753878           0.0
# 45   0.805392      -0.814526       -0.908068           0.0
# 42  -1.033403      -0.851988        1.558970           0.0
#
#      annual_income_outliers  spending_score_outliers    Female      Male
# 43                -0.084819                      0.0 -1.154701  1.154701
# 192               -0.084819                      0.0  0.866025 -0.866025
# 27                -0.084819                      0.0  0.866025 -0.866025
# 45                -0.084819                      0.0  0.866025 -0.866025
# 42                -0.084819                      0.0 -1.154701  1.154701

# %%
scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
train_scaled, test_scaled, scaler = wm.mall_clean()

# %%
train_scaled.head()
# Out:
#           age  annual_income  spending_score  age_outliers  \
# 43   0.731840      -0.814526       -0.599688           0.0
# 192 -0.444988       1.583028        0.672378           0.0
# 27   0.511185      -1.226606       -0.753878           0.0
# 45   0.805392      -0.814526       -0.908068           0.0
# 42  -1.033403      -0.851988        1.558970           0.0
#
#      annual_income_outliers  spending_score_outliers    Female      Male
# 43                -0.084819                      0.0 -1.154701  1.154701
# 192               -0.084819                      0.0  0.866025 -0.866025
# 27                -0.084819                      0.0  0.866025 -0.866025
# 45                -0.084819                      0.0  0.866025 -0.866025
# 42                -0.084819                      0.0 -1.154701  1.154701
